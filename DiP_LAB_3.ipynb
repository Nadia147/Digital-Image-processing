# %% [markdown]
# <a href="https://colab.research.google.com/github/Nadia147/Disital-Image-processing/blob/main/DiP_LAB_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from numpy.lib.function_base import kaiser
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img=cv2.imread('/content/drive/MyDrive/Colab Notebooks/DIP Lab Manual 3_files/image007.png')

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=410x413 at 0x7F7BD66ECC90>

# %% [markdown]
# Plotting the Histogram of Image (not using Buildin function)

# %%
histg = cv2.calcHist([img],[0],None,[256],[0,256]) 
import cv2
  
from matplotlib import pyplot as plt
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  

plt.plot(histr)
plt.show()

# %%
import cv2
  
from matplotlib import pyplot as plt
r,c,v=img.shape

h=np.zeros(256)
for i in range(r):
  for j in range(c):
    h[img[i][j]]+=1
       
x=np.arange(0,256,1)
plt.plot(x,h)

#plt.plot(histr)
plt.show()

# %%
r,c,v=img.shape
s=100
for i in range(r):
  for j in range(c):
    for k in range(3):
     if img[i][j][k]>s:
      img[i][j][k]=255
     else:
      img[i][j][k]=0
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=410x413 at 0x7F7BD662E4D0>

# %%
import cv2
  
from matplotlib import pyplot as plt

h=np.zeros(256)
for i in range(r):
  for j in range(c):
    h[img[i][j]]+=1
       
x=np.arange(0,256,1)
plt.plot(x,h)

#plt.plot(histr)
plt.show()

# %%
img=cv2.imread('/content/drive/MyDrive/Colab Notebooks/DIP Lab Manual 3_files/image007.png')
img=cv2.resize(img,(100,100))
img=img[:,:,0]
ev=np.zeros(5000)
od=np.zeros(5000)
k=0
l=0
#gg=r*c
for i in range(0,100):
  for j in range(0,100):
    s=((i*100)+j)%2
    if s==0:
      ev[k]=img[i][j]
      k=k+1
    else:
      od[l]=img[i][j]
      l=l+1


p=np.arange(0,5000,1)
plt.scatter(p,ev)
plt.scatter(p,od)
plt.show()
plt.scatter(ev,od)
plt.show()
